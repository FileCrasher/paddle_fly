# %% [markdown]
# # 项目简介
# ## 1背景
#
# <img src='https://ai-studio-static-online.cdn.bcebos.com/e39d60087f964cfe9e2aceef1b158a7c773835a46c5545d7a7ead927738b8dca'/>
#
#
# >为了防止类似的塌陷再次发生，为了守护国民的安全，拟定这里有一款无人机，它能够搭载GPS模块，搭载算力机构(如Nano)，一边飞一边检测桥面或路面的裂痕缺陷，一旦检测到了就发送实时位置给工程师，让抢修队及时到达现场...那将多么梦幻！
#
# >本应该是全套流程下来加上部署，但因训练时间赶不上DDL,所以只取其中的bridge_crack_1中的600多张图片进行训练，而且没有硬件支持，部署大概也就做个模型转换
#
#
# ## 2参考项目
# - [PaddleSeg：华录杯·车道线检测（单卡、多卡训练）](https://aistudio.baidu.com/aistudio/projectdetail/1081298?channelType=0&channel=0)

# %% [markdown]
# # 数据集介绍
# ### 1.1缺陷样例
# <img src='https://ai-studio-static-online.cdn.bcebos.com/13496de92a8c404687c5284adaccdead89ac66b0fabd45ab821530ed4aca925d'/>
#
# ### 1.2标注示例
# 采用EasyDL标注,过程中标注质量参差不齐,怀疑团队里有🐖
#
# 建议提前协商好统一的标注工具
#
# | 标注前 | 标注后 |
# | --- | --- |
# | ![](https://ai-studio-static-online.cdn.bcebos.com/af437a0dc1f94b62b3fec2f67ab91d1a19d889f34fea44028c53605f1820a8ae) | ![](https://ai-studio-static-online.cdn.bcebos.com/01a344215127408fa1a5b0b94439f42e8c5049bba8f94b65833edaa8a0abb707) |
#
#
# ### 1.3评审规则
# $$mIoU = \frac{1}{C}\sum_{c=1}^C{IoU_c}\tag{1.1}$$
# $$IoU_c = \frac{TP}{TP+FP+FN} \tag{1.2}$$
# $$TP = {\sum_i}{\parallel{M_ci\cdot{M_ci^*}}\parallel}_0\tag{1.3}$$
# $$FP = {\sum_i}{\parallel{M_ci\cdot{(1-M_ci^*)}}\parallel}_0\tag{1.4}$$
# $$TP = {\sum_i}{\parallel{(1-M_ci)\cdot{M_ci^*}}\parallel}_0\tag{1.5}$$
# $其中，C是分类数，在本任务中就是缺陷的类别数，TP, FP 和TN 表示true-positive, false-positive 和 false-negative。$

# %% [markdown]
# ## 1.环境配置
#
# - PaddleSeg release 2.2
# - PaddlePaddle 2.0.2

# %%
# !git clone https://gitee.com/paddlepaddle/PaddleSeg.git
#此操作会刷新你的PaddleSeg配置

# %%
# %cd PaddleSeg
# !pip install -r requirements.txt

# %% [markdown]
# ## 2.解压数据集
# 真的很解压

# %% [markdown]
# ### 2.1数据转换
# <font color=red size=5>注：标注后的数据集往往只生成一个.json文件和原图.png，如果使用LabelMe标注，请使用PaddleSeg->tools->labelme2seg.py转换数据为PaddleSeg可用的格式。如果用EasyDL的多边形工具，则用我改动的PaddleSeg->tools->easydl2seg.py</font>
# ```
# data                 # Root directory
# |-- annotations            # Ground-truth
# |   |-- xxx.png            # Pixel-level truth information
# |   |...
# |-- class_names.txt        # The category name of the dataset
# |-- xxx.jpg(png or other)  # Original image of dataset
# |-- ...
# |-- xxx.json               # Json file,used to save annotation information
# |-- ...
# ```
# 名字"annotations", "class_names.txt"不要轻易改动，否则更改源码

# %%
# 解压数据集
# !unzip ../data/data104136/bridge_crack_1.zip -d ./dataset/bridge

# %%
#解压数据集
# !unzip ../data/data104352/data.zip -d ./dataset/bridge

# %%
#此行转换数据集，生成mask在annotations里
# !python PaddleSeg/tools/easydl2seg.py PaddleSeg/dataset/bridge/data

# %% [markdown]
# ### 2.2看一眼生成的mask
# > 颜色有点阴间，你可以自己在标注的时候设置颜色
#
# <img src="https://ai-studio-static-online.cdn.bcebos.com/a950ce96038943ef8c032ec739c1dd917cb5516f51324781b49c5b7cf85a089e" width='300' height="300"/>

# %% [markdown]
# ## 3.转换&划分数据集
# ### 3.1转换数据集为PaddleSeg可用的形式。转换时遇到大坑：
# - EasyDL标注后的原始数据不能直接用于PaddleSeg下```tools/labelme2seg.py```，需要自己更改源码```PaddleSeg/tools/easydl2seg.py```。目前只支持多边形转换，brush工具不会。
# - 标注一定要多找些人
# - 使用```python tools/labelme2seg.py legacy/docs/annotation/labelme_demo/```时后面的绝对路径不能带中文，不然转换的时候会报错
# <img src ="https://ai-studio-static-online.cdn.bcebos.com/c431fc043b744873a7e8b9357696dc4ef9dc5b03e30c48148a74d0b2889bf335" width ="300" height ="300"/>

# %%
# !python makelist.py
#此时生成了train_list.txt(80%) val_list.txt(20%)
# Out:
# 2280108.ipynb  data  PaddleSeg	work

# %% [markdown]
# ## 4.开始训练
# ### 4.1选择模型
# 选择Cityscapes预训练模型
# |模型|数据集合|下载地址|outer stride|
# |---|---|---|---|
# |DeepLabv3+/MobileNetv3_Large/bn|Cityscapes|[deeplabv3p_mobilenetv3_large_cityscapes.tar.gz](https://paddleseg.bj.bcebos.com/models/deeplabv3p_mobilenetv3_large_cityscapes.tar.gz)|32|
# #### DeepLabv3+模型介绍
# >DeepLabv3+ [2] 是DeepLab系列的最后一篇文章，其前作有 DeepLabv1, DeepLabv2, DeepLabv3. 在最新作中，作者通过encoder-decoder进行多尺度信息的融合，以优化分割效果，尤其是目标边缘的效果。 并且其使用了Xception模型作为骨干网络，并将深度可分离卷积(depthwise separable convolution)应用到atrous spatial pyramid pooling(ASPP)中和decoder模块，提高了语义分割的健壮性和运行速率，在 PASCAL VOC 2012 和 Cityscapes 数据集上取得新的state-of-art performance.
#
# ![](https://ai-studio-static-online.cdn.bcebos.com/9fac26f996194e93adef88f60ee17088fadc02aaad294e4880af0c0e3e245112)
#
# ### 4.2[类别不均衡问题](https://github.com/PaddlePaddle/PaddleSeg/blob/release/2.2/docs/lovasz_loss.md)处理：
# > 在图像分割任务中，经常出现类别分布不均匀的情况
#
# > 例如：工业产品的瑕疵检测、道路提取及病变区域提取等。
#
# > 我们可使用lovasz loss解决这个问题。[参考文献](https://openaccess.thecvf.com/content_cvpr_2018/html/Berman_The_LovaSz-Softmax_Loss_CVPR_2018_paper.html)
#
# >Lovasz loss根据分割目标的类别数量可分为两种：```lovasz hinge loss```和```lovasz softmax loss```. 其中```lovasz hinge loss```适用于二分类问题，```lovasz softmax loss```适用于多分类问题。我们本次只有两类：\_background_和crack类，选用```lovasz hinge loss```

# %% [markdown]
# - 参考yml文件，输入图像大小为1024x1024，故选用相应cityscapes预训练模型：
#
# - 时间足够的话，设置iters为40000或许能再往后磨精度
# ```_base_: '../_base_/cityscapes_1024x1024.yml'
#
# batch_size: 2
# iters: 10000
#
# model:
#   type: DeepLabV3P
#   backbone:
#     type: ResNet101_vd
#     output_stride: 8
#     multi_grid: [1, 2, 4]
#     pretrained:  https://bj.bcebos.com/paddleseg/dygraph/resnet101_vd_ssld.tar.gz
#   num_classes: 2
#   backbone_indices: [0, 3]
#   aspp_ratios: [1, 12, 24, 36]
#   aspp_out_channels: 256
#   align_corners: True
#   pretrained: null
#
# optimizer:
#   type: sgd
#   momentum: 0.9
#   weight_decay: 4.0e-5
#
#
#
# learning_rate:
#   value: 0.001
#   decay:
#     type: poly
#     power: 0.9
#     end_lr: 0.0001
#
#
# loss:
#   types:
#     - type: MixedLoss
#       losses:
#         - type: CrossEntropyLoss
#         - type: LovaszSoftmaxLoss
#       coef: [0.8, 0.2]
#   coef: [1]
#
#
# train_dataset:
#   type: Dataset
#   dataset_root: /home/aistudio/
#   train_path: train_list.txt
#   num_classes: 2
#   transforms:
#     - type: ResizeStepScaling
#       min_scale_factor: 0.5
#       max_scale_factor: 2.0
#       scale_step_size: 0.25
#     - type: RandomPaddingCrop
#       crop_size: [1024, 1024]
#     - type: RandomHorizontalFlip
#     - type: Normalize
#   mode: train
#
# val_dataset:
#   type: Dataset
#   dataset_root: /home/aistudio/
#   val_path: val_list.txt
#   num_classes: 2
#   transforms:
#     - type: Normalize
#   mode: val
# ```

# %%
# 回到原始目录
# %cd ~

# %%
# !python PaddleSeg/train.py \
--config PaddleSeg/configs/deeplabv3p/deeplabv3p_MobileNetv2_512x512.yml \
--do_eval \
--use_vdl \
# --resume_model output/iter_137000/ 恢复训练用
# Out:
# 2021-08-15 22:55:33 [INFO]	[TRAIN] epoch: 43, iter: 9850/10000, loss: 0.2297, lr: 0.000230, batch_cost: 1.5034, reader_cost: 0.00009, ips: 1.3303 samples/sec | ETA 00:03:45
# 2021-08-15 22:55:48 [INFO]	[TRAIN] epoch: 43, iter: 9860/10000, loss: 0.2180, lr: 0.000216, batch_cost: 1.5161, reader_cost: 0.00009, ips: 1.3192 samples/sec | ETA 00:03:32
# 2021-08-15 22:56:04 [INFO]	[TRAIN] epoch: 43, iter: 9870/10000, loss: 0.2253, lr: 0.000202, batch_cost: 1.5072, reader_cost: 0.00009, ips: 1.3269 samples/sec | ETA 00:03:15
# 2021-08-15 22:56:19 [INFO]	[TRAIN] epoch: 43, iter: 9880/10000, loss: 0.2121, lr: 0.000188, batch_cost: 1.5151, reader_cost: 0.00009, ips: 1.3201 samples/sec | ETA 00:03:01
# 2021-08-15 22:56:34 [INFO]	[TRAIN] epoch: 43, iter: 9890/10000, loss: 0.2353, lr: 0.000174, batch_cost: 1.5096, reader_cost: 0.00008, ips: 1.3248 samples/sec | ETA 00:02:46
# 2021-08-15 22:56:49 [INFO]	[TRAIN] epoch: 43, iter: 9900/10000, loss: 0.2425, lr: 0.000160, batch_cost: 1.5172, reader_cost: 0.00009, ips: 1.3182 samples/sec | ETA 00:02:31
# 2021-08-15 22:57:04 [INFO]	[TRAIN] epoch: 43, iter: 9910/10000, loss: 0.2038, lr: 0.000146, batch_cost: 1.5156, reader_cost: 0.00010, ips: 1.3196 samples/sec | ETA 00:02:16
# 2021-08-15 22:57:19 [INFO]	[TRAIN] epoch: 43, iter: 9920/10000, loss: 0.2723, lr: 0.000131, batch_cost: 1.5104, reader_cost: 0.00009, ips: 1.3242 samples/sec | ETA 00:02:00
# 2021-08-15 22:57:34 [INFO]	[TRAIN] epoch: 43, iter: 9930/10000, loss: 0.2649, lr: 0.000116, batch_cost: 1.5156, reader_cost: 0.00009, ips: 1.3196 samples/sec | ETA 00:01:46
# 2021-08-15 22:57:49 [INFO]	[TRAIN] epoch: 43, iter: 9940/10000, loss: 0.2420, lr: 0.000102, batch_cost: 1.5071, reader_cost: 0.00009, ips: 1.3270 samples/sec | ETA 00:01:30
# 2021-08-15 22:58:05 [INFO]	[TRAIN] epoch: 43, iter: 9950/10000, loss: 0.2097, lr: 0.000086, batch_cost: 1.5187, reader_cost: 0.00009, ips: 1.3169 samples/sec | ETA 00:01:15
# 2021-08-15 22:58:20 [INFO]	[TRAIN] epoch: 43, iter: 9960/10000, loss: 0.2307, lr: 0.000071, batch_cost: 1.5149, reader_cost: 0.00009, ips: 1.3202 samples/sec | ETA 00:01:00
# 2021-08-15 22:58:35 [INFO]	[TRAIN] epoch: 43, iter: 9970/10000, loss: 0.2083, lr: 0.000055, batch_cost: 1.5122, reader_cost: 0.00010, ips: 1.3226 samples/sec | ETA 00:00:45
# 2021-08-15 22:58:50 [INFO]	[TRAIN] epoch: 43, iter: 9980/10000, loss: 0.2174, lr: 0.000039, batch_cost: 1.5185, reader_cost: 0.00009, ips: 1.3171 samples/sec | ETA 00:00:30
# 2021-08-15 22:59:05 [INFO]	[TRAIN] epoch: 43, iter: 9990/10000, loss: 0.2554, lr: 0.000022, batch_cost: 1.5159, reader_cost: 0.00010, ips: 1.3194 samples/sec | ETA 00:00:15
# 2021-08-15 22:59:21 [INFO]	[TRAIN] epoch: 43, iter: 10000/10000, loss: 0.2398, lr: 0.000003, batch_cost: 1.5273, reader_cost: 0.00010, ips: 1.3095 samples/sec | ETA 00:00:00
# 2021-08-15 22:59:21 [INFO]	Start evaluating (total_samples: 186, total_iters: 186)...
# 186/186 [==============================] - 32s 171ms/step - batch_cost: 0.1704 - reader cost: 4.3437e-
# 2021-08-15 22:59:52 [INFO]	[EVAL] #Images: 186 mIoU: 0.5013 Acc: 0.9595 Kappa: 0.0760
# 2021-08-15 22:59:52 [INFO]	[EVAL] Class IoU:
# [0.9594 0.0432]
# 2021-08-15 22:59:52 [INFO]	[EVAL] Class Acc:
# [0.9615 0.4527]
# 2021-08-15 22:59:57 [INFO]	[EVAL] The model with the best validation mIoU (0.5237) was saved at iter 9000.
# <class 'paddle.nn.layer.pooling.AvgPool2D'>'s flops has been counted
# <class 'paddle.nn.layer.conv.Conv2D'>'s flops has been counted
# <class 'paddle.nn.layer.norm.BatchNorm2D'>'s flops has been counted
# <class 'paddle.nn.layer.activation.ReLU'>'s flops has been counted
# Cannot find suitable count function for <class 'paddle.nn.layer.pooling.MaxPool2D'>. Treat it as zero FLOPs.
# Cannot find suitable count function for <class 'paddleseg.models.layers.activation.Activation'>. Treat it as zero FLOPs.
# <class 'paddle.nn.layer.pooling.AdaptiveAvgPool2D'>'s flops has been counted
# <class 'paddle.nn.layer.common.Dropout'>'s flops has been counted
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/tensor/creation.py:143: DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   if data.dtype == np.object:
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/math_op_patch.py:238: UserWarning: The dtype of left and right variables are not the same, left dtype is VarType.FP32, but right dtype is VarType.INT32, the right dtype will convert to VarType.FP32
#   format(lhs_dtype, rhs_dtype, lhs_dtype))
# Total Flops: 767760662528     Total Params: 45834226

# %% [markdown]
# ## 5.可视化训练（下次一定

# %% [markdown]
# ## 6.Pridict With TTA
# >TTA-Test Time Augmentation(测试时增强)
# > 和数据增广相似，TTA给你的测试数据进行了增广。目的是给你的测试数据随机调整(如下面的flip_horizontal，flip_vertical)。因此，除了常规的，“干净的”测试图像外，我们还会喂给训练后的模型增广后的图像，然后把一张图像的所有预测结果都列出来，取我们分数最高的作为最终结果，也算是提高ACC一个取巧的方法
#
# 这个图非常形象👇：FROM--[GT](https://github.com/AgentMaker/PaTTA)
#
# ```
# 	   Input
#              |           # input batch of images
#         / / /|\ \ \      # apply augmentations (flips, rotation, scale, etc.)
#        | | | | | | |     # pass augmented batches through model
#        | | | | | | |     # reverse transformations for each batch of masks/labels
#         \ \ \|/ / /      # merge predictions (mean, max, gmean, etc.)
#              |           # output batch of masks/labels
#            Output
# ```

# %%
# !python PaddleSeg/predict.py --config PaddleSeg/configs/deeplabv3p/deeplabv3p_MobileNetv2_512x512.yml \
--model_path output/best_model/model.pdparams \
--image_path infer \
--save_dir output/result\
--aug_pred \
--flip_horizontal \
--flip_vertical
# Out:
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/layers/utils.py:26: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   def convert_to_list(value, n, name, dtype=np.int):
# 2021-08-15 23:01:57 [INFO]
# ---------------Config Information---------------
# batch_size: 2
# iters: 10000
# learning_rate:
#   decay:
#     end_lr: 0.0001
#     power: 0.9
#     type: poly
#   value: 0.001
# loss:
#   coef:
#   - 1
#   types:
#   - coef:
#     - 0.8
#     - 0.2
#     losses:
#     - type: CrossEntropyLoss
#     - type: LovaszSoftmaxLoss
#     type: MixedLoss
# lr_scheduler:
#   end_lr: 0
#   learning_rate: 0.01
#   power: 0.9
#   type: PolynomialDecay
# model:
#   align_corners: true
#   aspp_out_channels: 256
#   aspp_ratios:
#   - 1
#   - 12
#   - 24
#   - 36
#   backbone:
#     multi_grid:
#     - 1
#     - 2
#     - 4
#     output_stride: 8
#     pretrained: https://bj.bcebos.com/paddleseg/dygraph/resnet101_vd_ssld.tar.gz
#     type: ResNet101_vd
#   backbone_indices:
#   - 0
#   - 3
#   num_classes: 2
#   pretrained: null
#   type: DeepLabV3P
# optimizer:
#   momentum: 0.9
#   type: sgd
#   weight_decay: 4.0e-05
# train_dataset:
#   dataset_root: /home/aistudio/
#   mode: train
#   num_classes: 2
#   train_path: train_list.txt
#   transforms:
#   - max_scale_factor: 2.0
#     min_scale_factor: 0.5
#     scale_step_size: 0.25
#     type: ResizeStepScaling
#   - crop_size:
#     - 1024
#     - 1024
#     type: RandomPaddingCrop
#   - type: RandomHorizontalFlip
#   - type: Normalize
#   type: Dataset
# val_dataset:
#   dataset_root: /home/aistudio/
#   mode: val
#   num_classes: 2
#   transforms:
#   - type: Normalize
#   type: Dataset
#   val_path: val_list.txt
# ------------------------------------------------
# W0815 23:01:57.144094 29071 device_context.cc:362] Please NOTE: device: 0, GPU Compute Capability: 7.0, Driver API Version: 11.0, Runtime API Version: 10.1
# W0815 23:01:57.144141 29071 device_context.cc:372] device: 0, cuDNN Version: 7.6.
# 2021-08-15 23:02:00 [INFO]	Loading pretrained model from https://bj.bcebos.com/paddleseg/dygraph/resnet101_vd_ssld.tar.gz
# 2021-08-15 23:02:00,142 - INFO - Lock 140285441576080 acquired on /home/aistudio/.paddleseg/tmp/resnet101_vd_ssld
# 2021-08-15 23:02:00,142 - INFO - Lock 140285441576080 released on /home/aistudio/.paddleseg/tmp/resnet101_vd_ssld
# 2021-08-15 23:02:01 [INFO]	There are 530/530 variables loaded into ResNet_vd.
# 2021-08-15 23:02:01 [INFO]	Number of predict images = 7
# 2021-08-15 23:02:01 [INFO]	Loading pretrained model from output/best_model/model.pdparams
# 2021-08-15 23:02:03 [INFO]	There are 615/615 variables loaded into DeepLabV3P.
# 2021-08-15 23:02:03 [INFO]	Start to predict...
# 7/7 [==============================] - 5s 785ms/st

# %% [markdown]
# 可视化预测结果：一言难尽。果然用600多张训练还是太少了
#
# 改进：
#
# - 训练数据预计增加到1800张
# - 调参
#
# <img src = "https://ai-studio-static-online.cdn.bcebos.com/520129bb0458436eae45fcf0ecc41b7e0dbd4910ee0d40e3a10c58c6ee40405e" width = "300" height = "300" />

# %% [markdown]
# ## 7.导出模型
# - 为后面OPT转换做准备

# %% [markdown]
# ### 7.1模型导出为静态图
# ```
# output
#   ├── deploy.yaml            # 部署相关的配置文件
#   ├── model.pdiparams        # 静态图模型参数
#   ├── model.pdiparams.info   # 参数额外信息，一般无需关注
#   └── model.pdmodel          # 静态图模型文件
# ```

# %%
# !python PaddleSeg/export.py \
       --config PaddleSeg/configs/bisenet/bisenet_cityscapes_1024x1024_160k.yml \
       --model_path output/best_model/model.pdparams
# Out:
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/layers/utils.py:26: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   def convert_to_list(value, n, name, dtype=np.int):
# W0815 23:06:13.039078 29613 device_context.cc:362] Please NOTE: device: 0, GPU Compute Capability: 7.0, Driver API Version: 11.0, Runtime API Version: 10.1
# W0815 23:06:13.044057 29613 device_context.cc:372] device: 0, cuDNN Version: 7.6.
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for db.convs.0._conv.weight. db.convs.0._conv.weight is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for db.convs.0._conv.bias. db.convs.0._conv.bias is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for db.convs.0._batch_norm.weight. db.convs.0._batch_norm.weight is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for db.convs.0._batch_norm.bias. db.convs.0._batch_norm.bias is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for db.convs.0._batch_norm._mean. db.convs.0._batch_norm._mean is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for db.convs.0._batch_norm._variance. db.convs.0._batch_norm._variance is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for db.convs.1._conv.weight. db.convs.1._conv.weight is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for db.convs.1._conv.bias. db.convs.1._conv.bias is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for db.convs.1._batch_norm.weight. db.convs.1._batch_norm.weight is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for db.convs.1._batch_norm.bias. db.convs.1._batch_norm.bias is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for db.convs.1._batch_norm._mean. db.convs.1._batch_norm._mean is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for db.convs.1._batch_norm._variance. db.convs.1._batch_norm._variance is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for db.convs.2._conv.weight. db.convs.2._conv.weight is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for db.convs.2._conv.bias. db.convs.2._conv.bias is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for db.convs.2._batch_norm.weight. db.convs.2._batch_norm.weight is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for db.convs.2._batch_norm.bias. db.convs.2._batch_norm.bias is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for db.convs.2._batch_norm._mean. db.convs.2._batch_norm._mean is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for db.convs.2._batch_norm._variance. db.convs.2._batch_norm._variance is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for db.convs.3._conv.weight. db.convs.3._conv.weight is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for db.convs.3._conv.bias. db.convs.3._conv.bias is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for db.convs.3._batch_norm.weight. db.convs.3._batch_norm.weight is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for db.convs.3._batch_norm.bias. db.convs.3._batch_norm.bias is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for db.convs.3._batch_norm._mean. db.convs.3._batch_norm._mean is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for db.convs.3._batch_norm._variance. db.convs.3._batch_norm._variance is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for db.convs.4._conv.weight. db.convs.4._conv.weight is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for db.convs.4._conv.bias. db.convs.4._conv.bias is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for db.convs.4._batch_norm.weight. db.convs.4._batch_norm.weight is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for db.convs.4._batch_norm.bias. db.convs.4._batch_norm.bias is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for db.convs.4._batch_norm._mean. db.convs.4._batch_norm._mean is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for db.convs.4._batch_norm._variance. db.convs.4._batch_norm._variance is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for db.convs.5._conv.weight. db.convs.5._conv.weight is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for db.convs.5._conv.bias. db.convs.5._conv.bias is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for db.convs.5._batch_norm.weight. db.convs.5._batch_norm.weight is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for db.convs.5._batch_norm.bias. db.convs.5._batch_norm.bias is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for db.convs.5._batch_norm._mean. db.convs.5._batch_norm._mean is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for db.convs.5._batch_norm._variance. db.convs.5._batch_norm._variance is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for db.convs.6._conv.weight. db.convs.6._conv.weight is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for db.convs.6._conv.bias. db.convs.6._conv.bias is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for db.convs.6._batch_norm.weight. db.convs.6._batch_norm.weight is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for db.convs.6._batch_norm.bias. db.convs.6._batch_norm.bias is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for db.convs.6._batch_norm._mean. db.convs.6._batch_norm._mean is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for db.convs.6._batch_norm._variance. db.convs.6._batch_norm._variance is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for db.convs.7._conv.weight. db.convs.7._conv.weight is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for db.convs.7._conv.bias. db.convs.7._conv.bias is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for db.convs.7._batch_norm.weight. db.convs.7._batch_norm.weight is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for db.convs.7._batch_norm.bias. db.convs.7._batch_norm.bias is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for db.convs.7._batch_norm._mean. db.convs.7._batch_norm._mean is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for db.convs.7._batch_norm._variance. db.convs.7._batch_norm._variance is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for sb.stem.conv._conv.weight. sb.stem.conv._conv.weight is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for sb.stem.conv._conv.bias. sb.stem.conv._conv.bias is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for sb.stem.conv._batch_norm.weight. sb.stem.conv._batch_norm.weight is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for sb.stem.conv._batch_norm.bias. sb.stem.conv._batch_norm.bias is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for sb.stem.conv._batch_norm._mean. sb.stem.conv._batch_norm._mean is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for sb.stem.conv._batch_norm._variance. sb.stem.conv._batch_norm._variance is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for sb.stem.left.0._conv.weight. sb.stem.left.0._conv.weight is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for sb.stem.left.0._conv.bias. sb.stem.left.0._conv.bias is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for sb.stem.left.0._batch_norm.weight. sb.stem.left.0._batch_norm.weight is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for sb.stem.left.0._batch_norm.bias. sb.stem.left.0._batch_norm.bias is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for sb.stem.left.0._batch_norm._mean. sb.stem.left.0._batch_norm._mean is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for sb.stem.left.0._batch_norm._variance. sb.stem.left.0._batch_norm._variance is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for sb.stem.left.1._conv.weight. sb.stem.left.1._conv.weight is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for sb.stem.left.1._conv.bias. sb.stem.left.1._conv.bias is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for sb.stem.left.1._batch_norm.weight. sb.stem.left.1._batch_norm.weight is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for sb.stem.left.1._batch_norm.bias. sb.stem.left.1._batch_norm.bias is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for sb.stem.left.1._batch_norm._mean. sb.stem.left.1._batch_norm._mean is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for sb.stem.left.1._batch_norm._variance. sb.stem.left.1._batch_norm._variance is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for sb.stem.fuse._conv.weight. sb.stem.fuse._conv.weight is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for sb.stem.fuse._conv.bias. sb.stem.fuse._conv.bias is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for sb.stem.fuse._batch_norm.weight. sb.stem.fuse._batch_norm.weight is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for sb.stem.fuse._batch_norm.bias. sb.stem.fuse._batch_norm.bias is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for sb.stem.fuse._batch_norm._mean. sb.stem.fuse._batch_norm._mean is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for sb.stem.fuse._batch_norm._variance. sb.stem.fuse._batch_norm._variance is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for sb.stage3.0.branch_1.0._conv.weight. sb.stage3.0.branch_1.0._conv.weight is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for sb.stage3.0.branch_1.0._conv.bias. sb.stage3.0.branch_1.0._conv.bias is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for sb.stage3.0.branch_1.0._batch_norm.weight. sb.stage3.0.branch_1.0._batch_norm.weight is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for sb.stage3.0.branch_1.0._batch_norm.bias. sb.stage3.0.branch_1.0._batch_norm.bias is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for sb.stage3.0.branch_1.0._batch_norm._mean. sb.stage3.0.branch_1.0._batch_norm._mean is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for sb.stage3.0.branch_1.0._batch_norm._variance. sb.stage3.0.branch_1.0._batch_norm._variance is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for sb.stage3.0.branch_1.1.depthwise_conv._conv.weight. sb.stage3.0.branch_1.1.depthwise_conv._conv.weight is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for sb.stage3.0.branch_1.1.depthwise_conv._conv.bias. sb.stage3.0.branch_1.1.depthwise_conv._conv.bias is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for sb.stage3.0.branch_1.1.depthwise_conv._batch_norm.weight. sb.stage3.0.branch_1.1.depthwise_conv._batch_norm.weight is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for sb.stage3.0.branch_1.1.depthwise_conv._batch_norm.bias. sb.stage3.0.branch_1.1.depthwise_conv._batch_norm.bias is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for sb.stage3.0.branch_1.1.depthwise_conv._batch_norm._mean. sb.stage3.0.branch_1.1.depthwise_conv._batch_norm._mean is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for sb.stage3.0.branch_1.1.depthwise_conv._batch_norm._variance. sb.stage3.0.branch_1.1.depthwise_conv._batch_norm._variance is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for sb.stage3.0.branch_1.2.depthwise_conv._conv.weight. sb.stage3.0.branch_1.2.depthwise_conv._conv.weight is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for sb.stage3.0.branch_1.2.depthwise_conv._conv.bias. sb.stage3.0.branch_1.2.depthwise_conv._conv.bias is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for sb.stage3.0.branch_1.2.depthwise_conv._batch_norm.weight. sb.stage3.0.branch_1.2.depthwise_conv._batch_norm.weight is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for sb.stage3.0.branch_1.2.depthwise_conv._batch_norm.bias. sb.stage3.0.branch_1.2.depthwise_conv._batch_norm.bias is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for sb.stage3.0.branch_1.2.depthwise_conv._batch_norm._mean. sb.stage3.0.branch_1.2.depthwise_conv._batch_norm._mean is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for sb.stage3.0.branch_1.2.depthwise_conv._batch_norm._variance. sb.stage3.0.branch_1.2.depthwise_conv._batch_norm._variance is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for sb.stage3.0.branch_1.3._conv.weight. sb.stage3.0.branch_1.3._conv.weight is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for sb.stage3.0.branch_1.3._conv.bias. sb.stage3.0.branch_1.3._conv.bias is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for sb.stage3.0.branch_1.3._batch_norm.weight. sb.stage3.0.branch_1.3._batch_norm.weight is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for sb.stage3.0.branch_1.3._batch_norm.bias. sb.stage3.0.branch_1.3._batch_norm.bias is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for sb.stage3.0.branch_1.3._batch_norm._mean. sb.stage3.0.branch_1.3._batch_norm._mean is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for sb.stage3.0.branch_1.3._batch_norm._variance. sb.stage3.0.branch_1.3._batch_norm._variance is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for sb.stage3.0.branch_2.0.depthwise_conv._conv.weight. sb.stage3.0.branch_2.0.depthwise_conv._conv.weight is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for sb.stage3.0.branch_2.0.depthwise_conv._conv.bias. sb.stage3.0.branch_2.0.depthwise_conv._conv.bias is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for sb.stage3.0.branch_2.0.depthwise_conv._batch_norm.weight. sb.stage3.0.branch_2.0.depthwise_conv._batch_norm.weight is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for sb.stage3.0.branch_2.0.depthwise_conv._batch_norm.bias. sb.stage3.0.branch_2.0.depthwise_conv._batch_norm.bias is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for sb.stage3.0.branch_2.0.depthwise_conv._batch_norm._mean. sb.stage3.0.branch_2.0.depthwise_conv._batch_norm._mean is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for sb.stage3.0.branch_2.0.depthwise_conv._batch_norm._variance. sb.stage3.0.branch_2.0.depthwise_conv._batch_norm._variance is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for sb.stage3.0.branch_2.1._conv.weight. sb.stage3.0.branch_2.1._conv.weight is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for sb.stage3.0.branch_2.1._conv.bias. sb.stage3.0.branch_2.1._conv.bias is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for sb.stage3.0.branch_2.1._batch_norm.weight. sb.stage3.0.branch_2.1._batch_norm.weight is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for sb.stage3.0.branch_2.1._batch_norm.bias. sb.stage3.0.branch_2.1._batch_norm.bias is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for sb.stage3.0.branch_2.1._batch_norm._mean. sb.stage3.0.branch_2.1._batch_norm._mean is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for sb.stage3.0.branch_2.1._batch_norm._variance. sb.stage3.0.branch_2.1._batch_norm._variance is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for sb.stage3.1.conv.0._conv.weight. sb.stage3.1.conv.0._conv.weight is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for sb.stage3.1.conv.0._conv.bias. sb.stage3.1.conv.0._conv.bias is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for sb.stage3.1.conv.0._batch_norm.weight. sb.stage3.1.conv.0._batch_norm.weight is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for sb.stage3.1.conv.0._batch_norm.bias. sb.stage3.1.conv.0._batch_norm.bias is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for sb.stage3.1.conv.0._batch_norm._mean. sb.stage3.1.conv.0._batch_norm._mean is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for sb.stage3.1.conv.0._batch_norm._variance. sb.stage3.1.conv.0._batch_norm._variance is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for sb.stage3.1.conv.1.depthwise_conv._conv.weight. sb.stage3.1.conv.1.depthwise_conv._conv.weight is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for sb.stage3.1.conv.1.depthwise_conv._conv.bias. sb.stage3.1.conv.1.depthwise_conv._conv.bias is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for sb.stage3.1.conv.1.depthwise_conv._batch_norm.weight. sb.stage3.1.conv.1.depthwise_conv._batch_norm.weight is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for sb.stage3.1.conv.1.depthwise_conv._batch_norm.bias. sb.stage3.1.conv.1.depthwise_conv._batch_norm.bias is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for sb.stage3.1.conv.1.depthwise_conv._batch_norm._mean. sb.stage3.1.conv.1.depthwise_conv._batch_norm._mean is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for sb.stage3.1.conv.1.depthwise_conv._batch_norm._variance. sb.stage3.1.conv.1.depthwise_conv._batch_norm._variance is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for sb.stage3.1.conv.2._conv.weight. sb.stage3.1.conv.2._conv.weight is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for sb.stage3.1.conv.2._conv.bias. sb.stage3.1.conv.2._conv.bias is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for sb.stage3.1.conv.2._batch_norm.weight. sb.stage3.1.conv.2._batch_norm.weight is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for sb.stage3.1.conv.2._batch_norm.bias. sb.stage3.1.conv.2._batch_norm.bias is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for sb.stage3.1.conv.2._batch_norm._mean. sb.stage3.1.conv.2._batch_norm._mean is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for sb.stage3.1.conv.2._batch_norm._variance. sb.stage3.1.conv.2._batch_norm._variance is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for sb.stage4.0.branch_1.0._conv.weight. sb.stage4.0.branch_1.0._conv.weight is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for sb.stage4.0.branch_1.0._conv.bias. sb.stage4.0.branch_1.0._conv.bias is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for sb.stage4.0.branch_1.0._batch_norm.weight. sb.stage4.0.branch_1.0._batch_norm.weight is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for sb.stage4.0.branch_1.0._batch_norm.bias. sb.stage4.0.branch_1.0._batch_norm.bias is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for sb.stage4.0.branch_1.0._batch_norm._mean. sb.stage4.0.branch_1.0._batch_norm._mean is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for sb.stage4.0.branch_1.0._batch_norm._variance. sb.stage4.0.branch_1.0._batch_norm._variance is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for sb.stage4.0.branch_1.1.depthwise_conv._conv.weight. sb.stage4.0.branch_1.1.depthwise_conv._conv.weight is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for sb.stage4.0.branch_1.1.depthwise_conv._conv.bias. sb.stage4.0.branch_1.1.depthwise_conv._conv.bias is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for sb.stage4.0.branch_1.1.depthwise_conv._batch_norm.weight. sb.stage4.0.branch_1.1.depthwise_conv._batch_norm.weight is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for sb.stage4.0.branch_1.1.depthwise_conv._batch_norm.bias. sb.stage4.0.branch_1.1.depthwise_conv._batch_norm.bias is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for sb.stage4.0.branch_1.1.depthwise_conv._batch_norm._mean. sb.stage4.0.branch_1.1.depthwise_conv._batch_norm._mean is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for sb.stage4.0.branch_1.1.depthwise_conv._batch_norm._variance. sb.stage4.0.branch_1.1.depthwise_conv._batch_norm._variance is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for sb.stage4.0.branch_1.2.depthwise_conv._conv.weight. sb.stage4.0.branch_1.2.depthwise_conv._conv.weight is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for sb.stage4.0.branch_1.2.depthwise_conv._conv.bias. sb.stage4.0.branch_1.2.depthwise_conv._conv.bias is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for sb.stage4.0.branch_1.2.depthwise_conv._batch_norm.weight. sb.stage4.0.branch_1.2.depthwise_conv._batch_norm.weight is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for sb.stage4.0.branch_1.2.depthwise_conv._batch_norm.bias. sb.stage4.0.branch_1.2.depthwise_conv._batch_norm.bias is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for sb.stage4.0.branch_1.2.depthwise_conv._batch_norm._mean. sb.stage4.0.branch_1.2.depthwise_conv._batch_norm._mean is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for sb.stage4.0.branch_1.2.depthwise_conv._batch_norm._variance. sb.stage4.0.branch_1.2.depthwise_conv._batch_norm._variance is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for sb.stage4.0.branch_1.3._conv.weight. sb.stage4.0.branch_1.3._conv.weight is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for sb.stage4.0.branch_1.3._conv.bias. sb.stage4.0.branch_1.3._conv.bias is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for sb.stage4.0.branch_1.3._batch_norm.weight. sb.stage4.0.branch_1.3._batch_norm.weight is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for sb.stage4.0.branch_1.3._batch_norm.bias. sb.stage4.0.branch_1.3._batch_norm.bias is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for sb.stage4.0.branch_1.3._batch_norm._mean. sb.stage4.0.branch_1.3._batch_norm._mean is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for sb.stage4.0.branch_1.3._batch_norm._variance. sb.stage4.0.branch_1.3._batch_norm._variance is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for sb.stage4.0.branch_2.0.depthwise_conv._conv.weight. sb.stage4.0.branch_2.0.depthwise_conv._conv.weight is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# ...
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for bga.conv._batch_norm._variance. bga.conv._batch_norm._variance is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for aux_head1.conv_3x3.0._conv.weight. aux_head1.conv_3x3.0._conv.weight is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for aux_head1.conv_3x3.0._conv.bias. aux_head1.conv_3x3.0._conv.bias is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for aux_head1.conv_3x3.0._batch_norm.weight. aux_head1.conv_3x3.0._batch_norm.weight is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for aux_head1.conv_3x3.0._batch_norm.bias. aux_head1.conv_3x3.0._batch_norm.bias is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for aux_head1.conv_3x3.0._batch_norm._mean. aux_head1.conv_3x3.0._batch_norm._mean is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for aux_head1.conv_3x3.0._batch_norm._variance. aux_head1.conv_3x3.0._batch_norm._variance is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for aux_head1.conv_1x1.weight. aux_head1.conv_1x1.weight is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for aux_head1.conv_1x1.bias. aux_head1.conv_1x1.bias is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for aux_head2.conv_3x3.0._conv.weight. aux_head2.conv_3x3.0._conv.weight is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for aux_head2.conv_3x3.0._conv.bias. aux_head2.conv_3x3.0._conv.bias is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for aux_head2.conv_3x3.0._batch_norm.weight. aux_head2.conv_3x3.0._batch_norm.weight is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for aux_head2.conv_3x3.0._batch_norm.bias. aux_head2.conv_3x3.0._batch_norm.bias is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for aux_head2.conv_3x3.0._batch_norm._mean. aux_head2.conv_3x3.0._batch_norm._mean is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for aux_head2.conv_3x3.0._batch_norm._variance. aux_head2.conv_3x3.0._batch_norm._variance is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for aux_head2.conv_1x1.weight. aux_head2.conv_1x1.weight is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for aux_head2.conv_1x1.bias. aux_head2.conv_1x1.bias is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for aux_head3.conv_3x3.0._conv.weight. aux_head3.conv_3x3.0._conv.weight is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for aux_head3.conv_3x3.0._conv.bias. aux_head3.conv_3x3.0._conv.bias is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for aux_head3.conv_3x3.0._batch_norm.weight. aux_head3.conv_3x3.0._batch_norm.weight is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for aux_head3.conv_3x3.0._batch_norm.bias. aux_head3.conv_3x3.0._batch_norm.bias is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for aux_head3.conv_3x3.0._batch_norm._mean. aux_head3.conv_3x3.0._batch_norm._mean is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for aux_head3.conv_3x3.0._batch_norm._variance. aux_head3.conv_3x3.0._batch_norm._variance is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for aux_head3.conv_1x1.weight. aux_head3.conv_1x1.weight is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for aux_head3.conv_1x1.bias. aux_head3.conv_1x1.bias is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for aux_head4.conv_3x3.0._conv.weight. aux_head4.conv_3x3.0._conv.weight is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for aux_head4.conv_3x3.0._conv.bias. aux_head4.conv_3x3.0._conv.bias is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for aux_head4.conv_3x3.0._batch_norm.weight. aux_head4.conv_3x3.0._batch_norm.weight is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for aux_head4.conv_3x3.0._batch_norm.bias. aux_head4.conv_3x3.0._batch_norm.bias is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for aux_head4.conv_3x3.0._batch_norm._mean. aux_head4.conv_3x3.0._batch_norm._mean is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for aux_head4.conv_3x3.0._batch_norm._variance. aux_head4.conv_3x3.0._batch_norm._variance is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for aux_head4.conv_1x1.weight. aux_head4.conv_1x1.weight is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for aux_head4.conv_1x1.bias. aux_head4.conv_1x1.bias is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for head.conv_3x3.0._conv.weight. head.conv_3x3.0._conv.weight is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for head.conv_3x3.0._conv.bias. head.conv_3x3.0._conv.bias is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for head.conv_3x3.0._batch_norm.weight. head.conv_3x3.0._batch_norm.weight is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for head.conv_3x3.0._batch_norm.bias. head.conv_3x3.0._batch_norm.bias is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for head.conv_3x3.0._batch_norm._mean. head.conv_3x3.0._batch_norm._mean is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for head.conv_3x3.0._batch_norm._variance. head.conv_3x3.0._batch_norm._variance is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for head.conv_1x1.weight. head.conv_1x1.weight is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1303: UserWarning: Skip loading for head.conv_1x1.bias. head.conv_1x1.bias is not found in the provided dict.
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# 2021-08-15 23:06:17 [INFO]	Loaded trained params of model successfully.
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/layers/utils.py:77: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated, and in 3.8 it will stop working
#   return (isinstance(seq, collections.Sequence) and
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/layers/math_op_patch.py:298: UserWarning: /home/aistudio/PaddleSeg/paddleseg/models/bisenet.py:179
# The behavior of expression A + B has been unified with elementwise_add(X, Y, axis=-1) from Paddle 2.0. If your code works well in the older versions but crashes in this version, try to use elementwise_add(X, Y, axis=0) instead of A + B. This transitional warning will be dropped in the future.
#   op_type, op_type, EXPRESSION_MAP[method_name]))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/layers/math_op_patch.py:298: UserWarning: /home/aistudio/PaddleSeg/paddleseg/models/bisenet.py:157
# The behavior of expression A + B has been unified with elementwise_add(X, Y, axis=-1) from Paddle 2.0. If your code works well in the older versions but crashes in this version, try to use elementwise_add(X, Y, axis=0) instead of A + B. This transitional warning will be dropped in the future.
#   op_type, op_type, EXPRESSION_MAP[method_name]))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/layers/math_op_patch.py:298: UserWarning: /tmp/tmpbo2knx64.py:6
# The behavior of expression A + B has been unified with elementwise_add(X, Y, axis=-1) from Paddle 2.0. If your code works well in the older versions but crashes in this version, try to use elementwise_add(X, Y, axis=0) instead of A + B. This transitional warning will be dropped in the future.
#   op_type, op_type, EXPRESSION_MAP[method_name]))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/layers/math_op_patch.py:298: UserWarning: /tmp/tmp0wd00gl9.py:12
# The behavior of expression A * B has been unified with elementwise_mul(X, Y, axis=-1) from Paddle 2.0. If your code works well in the older versions but crashes in this version, try to use elementwise_mul(X, Y, axis=0) instead of A * B. This transitional warning will be dropped in the future.
#   op_type, op_type, EXPRESSION_MAP[method_name]))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/layers/math_op_patch.py:298: UserWarning: /tmp/tmp0wd00gl9.py:13
# The behavior of expression A * B has been unified with elementwise_mul(X, Y, axis=-1) from Paddle 2.0. If your code works well in the older versions but crashes in this version, try to use elementwise_mul(X, Y, axis=0) instead of A * B. This transitional warning will be dropped in the future.
#   op_type, op_type, EXPRESSION_MAP[method_name]))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/layers/math_op_patch.py:298: UserWarning: /tmp/tmp0wd00gl9.py:17
# The behavior of expression A + B has been unified with elementwise_add(X, Y, axis=-1) from Paddle 2.0. If your code works well in the older versions but crashes in this version, try to use elementwise_add(X, Y, axis=0) instead of A + B. This transitional warning will be dropped in the future.
#   op_type, op_type, EXPRESSION_MAP[method_name]))
# 2021-08-15 23:06:18 [INFO]	Model is saved in ./output.

# %% [markdown]
# ## 8.部署在安卓端 & OPT工具转换PaddleLite模型
# 使用OPT工具转换参数为PaddleLite能用的格式

# %%
# !chmod +x ./opt_linux
# !./opt_linux --model_file=output/model.pdmodel --param_file=output/model.pdiparams --optimize_out=Deeplab3p_MobileNetv3
# Out:
# [W  8/15 23: 7:24.743 /island/Paddle-Lite/lite/api/opt.cc RunOptimize:177] Load combined-param model. Option model_dir will be ignored
# [I  8/15 23: 7:24.743 /island/Paddle-Lite/lite/api/cxx_api.cc Build:295] Load model from file.
# [I  8/15 23: 7:24.780 ...island/Paddle-Lite/lite/core/optimizer.h:283 RunPasses] == Running pass: lite_quant_dequant_fuse_pass
# [I  8/15 23: 7:24.786 ...island/Paddle-Lite/lite/core/optimizer.h:307 RunPasses] == Finished running: lite_quant_dequant_fuse_pass
# [I  8/15 23: 7:24.786 ...island/Paddle-Lite/lite/core/optimizer.h:283 RunPasses] == Running pass: weight_quantization_preprocess_pass
# [I  8/15 23: 7:24.787 ...island/Paddle-Lite/lite/core/optimizer.h:307 RunPasses] == Finished running: weight_quantization_preprocess_pass
# [I  8/15 23: 7:24.787 ...island/Paddle-Lite/lite/core/optimizer.h:283 RunPasses] == Running pass: adaptive_1x1_pool2d_convert_global_pass
# [I  8/15 23: 7:24.787 ...island/Paddle-Lite/lite/core/optimizer.h:307 RunPasses] == Finished running: adaptive_1x1_pool2d_convert_global_pass
# [I  8/15 23: 7:24.787 ...island/Paddle-Lite/lite/core/optimizer.h:283 RunPasses] == Running pass: lite_conv_elementwise_fuse_pass
# [I  8/15 23: 7:24.795 ...le-Lite/lite/core/mir/pattern_matcher.cc:108 operator()] detected 40 subgraph
# [I  8/15 23: 7:24.798 ...le-Lite/lite/core/mir/pattern_matcher.cc:108 operator()] detected 16 subgraph
# [I  8/15 23: 7:24.799 ...island/Paddle-Lite/lite/core/optimizer.h:307 RunPasses] == Finished running: lite_conv_elementwise_fuse_pass
# [I  8/15 23: 7:24.799 ...island/Paddle-Lite/lite/core/optimizer.h:283 RunPasses] == Running pass: lite_conv_bn_fuse_pass
# [I  8/15 23: 7:24.817 ...le-Lite/lite/core/mir/pattern_matcher.cc:108 operator()] detected 36 subgraph
# [I  8/15 23: 7:24.826 ...le-Lite/lite/core/mir/pattern_matcher.cc:108 operator()] detected 16 subgraph
# [I  8/15 23: 7:24.831 ...island/Paddle-Lite/lite/core/optimizer.h:307 RunPasses] == Finished running: lite_conv_bn_fuse_pass
# [I  8/15 23: 7:24.831 ...island/Paddle-Lite/lite/core/optimizer.h:283 RunPasses] == Running pass: lite_conv_elementwise_fuse_pass
# [I  8/15 23: 7:24.835 ...island/Paddle-Lite/lite/core/optimizer.h:307 RunPasses] == Finished running: lite_conv_elementwise_fuse_pass
# [I  8/15 23: 7:24.835 ...island/Paddle-Lite/lite/core/optimizer.h:283 RunPasses] == Running pass: lite_conv_conv_fuse_pass
# [I  8/15 23: 7:24.836 ...island/Paddle-Lite/lite/core/optimizer.h:307 RunPasses] == Finished running: lite_conv_conv_fuse_pass
# [I  8/15 23: 7:24.836 ...island/Paddle-Lite/lite/core/optimizer.h:283 RunPasses] == Running pass: lite_conv_activation_fuse_pass
# [I  8/15 23: 7:24.839 ...le-Lite/lite/core/mir/pattern_matcher.cc:108 operator()] detected 22 subgraph
# [I  8/15 23: 7:24.847 ...island/Paddle-Lite/lite/core/optimizer.h:307 RunPasses] == Finished running: lite_conv_activation_fuse_pass
# [I  8/15 23: 7:24.847 ...island/Paddle-Lite/lite/core/optimizer.h:283 RunPasses] == Running pass: lite_var_conv_2d_activation_fuse_pass
# [I  8/15 23: 7:24.847 ...island/Paddle-Lite/lite/core/optimizer.h:296 RunPasses]    - Skip lite_var_conv_2d_activation_fuse_pass because the target or kernel does not match.
# [I  8/15 23: 7:24.847 ...island/Paddle-Lite/lite/core/optimizer.h:283 RunPasses] == Running pass: lite_match_matrix_activation_fuse_pass
# [I  8/15 23: 7:24.847 ...island/Paddle-Lite/lite/core/optimizer.h:296 RunPasses]    - Skip lite_match_matrix_activation_fuse_pass because the target or kernel does not match.
# [I  8/15 23: 7:24.847 ...island/Paddle-Lite/lite/core/optimizer.h:283 RunPasses] == Running pass: lite_squeeze2_matmul_fuse_pass
# [I  8/15 23: 7:24.847 ...island/Paddle-Lite/lite/core/optimizer.h:307 RunPasses] == Finished running: lite_squeeze2_matmul_fuse_pass
# [I  8/15 23: 7:24.847 ...island/Paddle-Lite/lite/core/optimizer.h:283 RunPasses] == Running pass: lite_reshape2_matmul_fuse_pass
# [I  8/15 23: 7:24.847 ...island/Paddle-Lite/lite/core/optimizer.h:307 RunPasses] == Finished running: lite_reshape2_matmul_fuse_pass
# [I  8/15 23: 7:24.847 ...island/Paddle-Lite/lite/core/optimizer.h:283 RunPasses] == Running pass: lite_matmul_fuse_pass
# [I  8/15 23: 7:24.847 ...island/Paddle-Lite/lite/core/optimizer.h:307 RunPasses] == Finished running: lite_matmul_fuse_pass
# [I  8/15 23: 7:24.847 ...island/Paddle-Lite/lite/core/optimizer.h:283 RunPasses] == Running pass: lite_fc_fuse_pass
# [I  8/15 23: 7:24.847 ...island/Paddle-Lite/lite/core/optimizer.h:307 RunPasses] == Finished running: lite_fc_fuse_pass
# [I  8/15 23: 7:24.847 ...island/Paddle-Lite/lite/core/optimizer.h:283 RunPasses] == Running pass: lite_shuffle_channel_fuse_pass
# [I  8/15 23: 7:24.848 ...island/Paddle-Lite/lite/core/optimizer.h:307 RunPasses] == Finished running: lite_shuffle_channel_fuse_pass
# [I  8/15 23: 7:24.848 ...island/Paddle-Lite/lite/core/optimizer.h:283 RunPasses] == Running pass: lite_transpose_softmax_transpose_fuse_pass
# [I  8/15 23: 7:24.848 ...island/Paddle-Lite/lite/core/optimizer.h:307 RunPasses] == Finished running: lite_transpose_softmax_transpose_fuse_pass
# [I  8/15 23: 7:24.848 ...island/Paddle-Lite/lite/core/optimizer.h:283 RunPasses] == Running pass: lite_interpolate_fuse_pass
# [I  8/15 23: 7:24.849 ...island/Paddle-Lite/lite/core/optimizer.h:307 RunPasses] == Finished running: lite_interpolate_fuse_pass
# [I  8/15 23: 7:24.849 ...island/Paddle-Lite/lite/core/optimizer.h:283 RunPasses] == Running pass: identity_scale_eliminate_pass
# [I  8/15 23: 7:24.849 ...le-Lite/lite/core/mir/pattern_matcher.cc:108 operator()] detected 1 subgraph
# [I  8/15 23: 7:24.849 ...island/Paddle-Lite/lite/core/optimizer.h:307 RunPasses] == Finished running: identity_scale_eliminate_pass
# [I  8/15 23: 7:24.849 ...island/Paddle-Lite/lite/core/optimizer.h:283 RunPasses] == Running pass: lite_scales_fuse_pass
# [I  8/15 23: 7:24.849 ...island/Paddle-Lite/lite/core/optimizer.h:296 RunPasses]    - Skip lite_scales_fuse_pass because the target or kernel does not match.
# [I  8/15 23: 7:24.849 ...island/Paddle-Lite/lite/core/optimizer.h:283 RunPasses] == Running pass: lite_sequence_reverse_embedding_fuse_pass
# [I  8/15 23: 7:24.849 ...island/Paddle-Lite/lite/core/optimizer.h:296 RunPasses]    - Skip lite_sequence_reverse_embedding_fuse_pass because the target or kernel does not match.
# [I  8/15 23: 7:24.849 ...island/Paddle-Lite/lite/core/optimizer.h:283 RunPasses] == Running pass: elementwise_mul_constant_eliminate_pass
# [I  8/15 23: 7:24.849 ...island/Paddle-Lite/lite/core/optimizer.h:307 RunPasses] == Finished running: elementwise_mul_constant_eliminate_pass
# [I  8/15 23: 7:24.849 ...island/Paddle-Lite/lite/core/optimizer.h:283 RunPasses] == Running pass: lite_sequence_pool_concat_fuse_pass
# [I  8/15 23: 7:24.849 ...island/Paddle-Lite/lite/core/optimizer.h:296 RunPasses]    - Skip lite_sequence_pool_concat_fuse_pass because the target or kernel does not match.
# [I  8/15 23: 7:24.849 ...island/Paddle-Lite/lite/core/optimizer.h:283 RunPasses] == Running pass: lite_scale_activation_fuse_pass
# [I  8/15 23: 7:24.850 ...island/Paddle-Lite/lite/core/optimizer.h:307 RunPasses] == Finished running: lite_scale_activation_fuse_pass
# [I  8/15 23: 7:24.850 ...island/Paddle-Lite/lite/core/optimizer.h:283 RunPasses] == Running pass: lite_instance_norm_activation_fuse_pass
# [I  8/15 23: 7:24.850 ...island/Paddle-Lite/lite/core/optimizer.h:296 RunPasses]    - Skip lite_instance_norm_activation_fuse_pass because the target or kernel does not match.
# [I  8/15 23: 7:24.850 ...island/Paddle-Lite/lite/core/optimizer.h:283 RunPasses] == Running pass: identity_dropout_eliminate_pass
# [I  8/15 23: 7:24.850 ...island/Paddle-Lite/lite/core/optimizer.h:296 RunPasses]    - Skip identity_dropout_eliminate_pass because the target or kernel does not match.
# [I  8/15 23: 7:24.850 ...island/Paddle-Lite/lite/core/optimizer.h:283 RunPasses] == Running pass: __xpu__resnet_fuse_pass
# [I  8/15 23: 7:24.850 ...island/Paddle-Lite/lite/core/optimizer.h:296 RunPasses]    - Skip __xpu__resnet_fuse_pass because the target or kernel does not match.
# [I  8/15 23: 7:24.850 ...island/Paddle-Lite/lite/core/optimizer.h:283 RunPasses] == Running pass: __xpu__resnet_d_fuse_pass
# [I  8/15 23: 7:24.850 ...island/Paddle-Lite/lite/core/optimizer.h:296 RunPasses]    - Skip __xpu__resnet_d_fuse_pass because the target or kernel does not match.
# [I  8/15 23: 7:24.850 ...island/Paddle-Lite/lite/core/optimizer.h:283 RunPasses] == Running pass: __xpu__resnet_cbam_fuse_pass
# [I  8/15 23: 7:24.850 ...island/Paddle-Lite/lite/core/optimizer.h:296 RunPasses]    - Skip __xpu__resnet_cbam_fuse_pass because the target or kernel does not match.
# [I  8/15 23: 7:24.850 ...island/Paddle-Lite/lite/core/optimizer.h:283 RunPasses] == Running pass: __xpu__conv2d_fuse_pass
# [I  8/15 23: 7:24.850 ...island/Paddle-Lite/lite/core/optimizer.h:296 RunPasses]    - Skip __xpu__conv2d_fuse_pass because the target or kernel does not match.
# [I  8/15 23: 7:24.850 ...island/Paddle-Lite/lite/core/optimizer.h:283 RunPasses] == Running pass: __xpu__resblock_reduction_fuse_pass
# [I  8/15 23: 7:24.850 ...island/Paddle-Lite/lite/core/optimizer.h:296 RunPasses]    - Skip __xpu__resblock_reduction_fuse_pass because the target or kernel does not match.
# [I  8/15 23: 7:24.850 ...island/Paddle-Lite/lite/core/optimizer.h:283 RunPasses] == Running pass: __xpu__resblock_normal_fuse_pass
# [I  8/15 23: 7:24.850 ...island/Paddle-Lite/lite/core/optimizer.h:296 RunPasses]    - Skip __xpu__resblock_normal_fuse_pass because the target or kernel does not match.
# [I  8/15 23: 7:24.850 ...island/Paddle-Lite/lite/core/optimizer.h:283 RunPasses] == Running pass: __xpu__conv2d_link_previous_out_max_pass
# [I  8/15 23: 7:24.850 ...island/Paddle-Lite/lite/core/optimizer.h:296 RunPasses]    - Skip __xpu__conv2d_link_previous_out_max_pass because the target or kernel does not match.
# [I  8/15 23: 7:24.850 ...island/Paddle-Lite/lite/core/optimizer.h:283 RunPasses] == Running pass: __xpu__sfa_head_meanstd_fuse_pass
# [I  8/15 23: 7:24.850 ...island/Paddle-Lite/lite/core/optimizer.h:296 RunPasses]    - Skip __xpu__sfa_head_meanstd_fuse_pass because the target or kernel does not match.
# [I  8/15 23: 7:24.850 ...island/Paddle-Lite/lite/core/optimizer.h:283 RunPasses] == Running pass: __xpu__sfa_head_moment_fuse_pass
# [I  8/15 23: 7:24.850 ...island/Paddle-Lite/lite/core/optimizer.h:296 RunPasses]    - Skip __xpu__sfa_head_moment_fuse_pass because the target or kernel does not match.
# [I  8/15 23: 7:24.850 ...island/Paddle-Lite/lite/core/optimizer.h:283 RunPasses] == Running pass: __xpu__mmdnn_fuse_pass
# [I  8/15 23: 7:24.850 ...island/Paddle-Lite/lite/core/optimizer.h:296 RunPasses]    - Skip __xpu__mmdnn_fuse_pass because the target or kernel does not match.
# [I  8/15 23: 7:24.850 ...island/Paddle-Lite/lite/core/optimizer.h:283 RunPasses] == Running pass: __xpu__multi_encoder_fuse_pass
# [I  8/15 23: 7:24.850 ...island/Paddle-Lite/lite/core/optimizer.h:296 RunPasses]    - Skip __xpu__multi_encoder_fuse_pass because the target or kernel does not match.
# [I  8/15 23: 7:24.850 ...island/Paddle-Lite/lite/core/optimizer.h:283 RunPasses] == Running pass: __xpu__embedding_with_eltwise_add_fuse_pass
# [I  8/15 23: 7:24.850 ...island/Paddle-Lite/lite/core/optimizer.h:296 RunPasses]    - Skip __xpu__embedding_with_eltwise_add_fuse_pass because the target or kernel does not match.
# [I  8/15 23: 7:24.850 ...island/Paddle-Lite/lite/core/optimizer.h:283 RunPasses] == Running pass: __xpu__fc_fuse_pass
# [I  8/15 23: 7:24.850 ...island/Paddle-Lite/lite/core/optimizer.h:296 RunPasses]    - Skip __xpu__fc_fuse_pass because the target or kernel does not match.
# [I  8/15 23: 7:24.850 ...island/Paddle-Lite/lite/core/optimizer.h:283 RunPasses] == Running pass: __xpu__softmax_topk_fuse_pass
# [I  8/15 23: 7:24.850 ...island/Paddle-Lite/lite/core/optimizer.h:296 RunPasses]    - Skip __xpu__softmax_topk_fuse_pass because the target or kernel does not match.
# [I  8/15 23: 7:24.850 ...island/Paddle-Lite/lite/core/optimizer.h:283 RunPasses] == Running pass: __xpu__multi_encoder_slice_link_fuse_pass
# [I  8/15 23: 7:24.850 ...island/Paddle-Lite/lite/core/optimizer.h:296 RunPasses]    - Skip __xpu__multi_encoder_slice_link_fuse_pass because the target or kernel does not match.
# [I  8/15 23: 7:24.850 ...island/Paddle-Lite/lite/core/optimizer.h:283 RunPasses] == Running pass: quantized_op_attributes_inference_pass
# [I  8/15 23: 7:24.850 ...island/Paddle-Lite/lite/core/optimizer.h:296 RunPasses]    - Skip quantized_op_attributes_inference_pass because the target or kernel does not match.
# [I  8/15 23: 7:24.850 ...island/Paddle-Lite/lite/core/optimizer.h:283 RunPasses] == Running pass: restrict_quantized_op_with_same_input_output_scale_pass
# [I  8/15 23: 7:24.850 ...island/Paddle-Lite/lite/core/optimizer.h:296 RunPasses]    - Skip restrict_quantized_op_with_same_input_output_scale_pass because the target or kernel does not match.
# [I  8/15 23: 7:24.850 ...island/Paddle-Lite/lite/core/optimizer.h:283 RunPasses] == Running pass: npu_subgraph_pass
# [I  8/15 23: 7:24.850 ...island/Paddle-Lite/lite/core/optimizer.h:296 RunPasses]    - Skip npu_subgraph_pass because the target or kernel does not match.
# [I  8/15 23: 7:24.850 ...island/Paddle-Lite/lite/core/optimizer.h:283 RunPasses] == Running pass: huawei_ascend_npu_subgraph_pass
# [I  8/15 23: 7:24.850 ...island/Paddle-Lite/lite/core/optimizer.h:296 RunPasses]    - Skip huawei_ascend_npu_subgraph_pass because the target or kernel does not match.
# [I  8/15 23: 7:24.850 ...island/Paddle-Lite/lite/core/optimizer.h:283 RunPasses] == Running pass: imagination_nna_subgraph_pass
# [I  8/15 23: 7:24.850 ...island/Paddle-Lite/lite/core/optimizer.h:296 RunPasses]    - Skip imagination_nna_subgraph_pass because the target or kernel does not match.
# [I  8/15 23: 7:24.850 ...island/Paddle-Lite/lite/core/optimizer.h:283 RunPasses] == Running pass: xpu_subgraph_pass
# [I  8/15 23: 7:24.850 ...island/Paddle-Lite/lite/core/optimizer.h:296 RunPasses]    - Skip xpu_subgraph_pass because the target or kernel does not match.
# [I  8/15 23: 7:24.850 ...island/Paddle-Lite/lite/core/optimizer.h:283 RunPasses] == Running pass: bm_subgraph_pass
# [I  8/15 23: 7:24.850 ...island/Paddle-Lite/lite/core/optimizer.h:296 RunPasses]    - Skip bm_subgraph_pass because the target or kernel does not match.
# [I  8/15 23: 7:24.850 ...island/Paddle-Lite/lite/core/optimizer.h:283 RunPasses] == Running pass: apu_subgraph_pass
# [I  8/15 23: 7:24.850 ...island/Paddle-Lite/lite/core/optimizer.h:296 RunPasses]    - Skip apu_subgraph_pass because the target or kernel does not match.
# [I  8/15 23: 7:24.850 ...island/Paddle-Lite/lite/core/optimizer.h:283 RunPasses] == Running pass: rknpu_subgraph_pass
# [I  8/15 23: 7:24.850 ...island/Paddle-Lite/lite/core/optimizer.h:296 RunPasses]    - Skip rknpu_subgraph_pass because the target or kernel does not match.
# [I  8/15 23: 7:24.850 ...island/Paddle-Lite/lite/core/optimizer.h:283 RunPasses] == Running pass: mlu_subgraph_pass
# [I  8/15 23: 7:24.850 ...island/Paddle-Lite/lite/core/optimizer.h:296 RunPasses]    - Skip mlu_subgraph_pass because the target or kernel does not match.
# [I  8/15 23: 7:24.850 ...island/Paddle-Lite/lite/core/optimizer.h:283 RunPasses] == Running pass: control_flow_op_unused_inputs_and_outputs_eliminate_pass
# [I  8/15 23: 7:24.850 ...island/Paddle-Lite/lite/core/optimizer.h:296 RunPasses]    - Skip control_flow_op_unused_inputs_and_outputs_eliminate_pass because the target or kernel does not match.
# [I  8/15 23: 7:24.850 ...island/Paddle-Lite/lite/core/optimizer.h:283 RunPasses] == Running pass: static_kernel_pick_pass
# [I  8/15 23: 7:24.856 ...island/Paddle-Lite/lite/core/optimizer.h:307 RunPasses] == Finished running: static_kernel_pick_pass
# [I  8/15 23: 7:24.856 ...island/Paddle-Lite/lite/core/optimizer.h:283 RunPasses] == Running pass: remove_tf_redundant_ops_pass
# [I  8/15 23: 7:24.861 ...island/Paddle-Lite/lite/core/optimizer.h:307 RunPasses] == Finished running: remove_tf_redundant_ops_pass
# [I  8/15 23: 7:24.861 ...island/Paddle-Lite/lite/core/optimizer.h:283 RunPasses] == Running pass: variable_place_inference_pass
# [I  8/15 23: 7:24.864 ...island/Paddle-Lite/lite/core/optimizer.h:307 RunPasses] == Finished running: variable_place_inference_pass
# [I  8/15 23: 7:24.864 ...island/Paddle-Lite/lite/core/optimizer.h:283 RunPasses] == Running pass: mlu_postprocess_pass
# [I  8/15 23: 7:24.864 ...island/Paddle-Lite/lite/core/optimizer.h:296 RunPasses]    - Skip mlu_postprocess_pass because the target or kernel does not match.
# [I  8/15 23: 7:24.864 ...island/Paddle-Lite/lite/core/optimizer.h:283 RunPasses] == Running pass: argument_type_display_pass
# [I  8/15 23: 7:24.864 ...island/Paddle-Lite/lite/core/optimizer.h:307 RunPasses] == Finished running: argument_type_display_pass
# [I  8/15 23: 7:24.864 ...island/Paddle-Lite/lite/core/optimizer.h:283 RunPasses] == Running pass: type_target_cast_pass
# [I  8/15 23: 7:24.865 ...island/Paddle-Lite/lite/core/optimizer.h:307 RunPasses] == Finished running: type_target_cast_pass
# [I  8/15 23: 7:24.865 ...island/Paddle-Lite/lite/core/optimizer.h:283 RunPasses] == Running pass: variable_place_inference_pass
# [I  8/15 23: 7:24.868 ...island/Paddle-Lite/lite/core/optimizer.h:307 RunPasses] == Finished running: variable_place_inference_pass
# [I  8/15 23: 7:24.868 ...island/Paddle-Lite/lite/core/optimizer.h:283 RunPasses] == Running pass: argument_type_display_pass
# [I  8/15 23: 7:24.868 ...island/Paddle-Lite/lite/core/optimizer.h:307 RunPasses] == Finished running: argument_type_display_pass
# [I  8/15 23: 7:24.868 ...island/Paddle-Lite/lite/core/optimizer.h:283 RunPasses] == Running pass: io_copy_kernel_pick_pass
# [I  8/15 23: 7:24.868 ...island/Paddle-Lite/lite/core/optimizer.h:307 RunPasses] == Finished running: io_copy_kernel_pick_pass
# [I  8/15 23: 7:24.868 ...island/Paddle-Lite/lite/core/optimizer.h:283 RunPasses] == Running pass: argument_type_display_pass
# [I  8/15 23: 7:24.868 ...island/Paddle-Lite/lite/core/optimizer.h:307 RunPasses] == Finished running: argument_type_display_pass
# [I  8/15 23: 7:24.868 ...island/Paddle-Lite/lite/core/optimizer.h:283 RunPasses] == Running pass: variable_place_inference_pass
# [I  8/15 23: 7:24.870 ...island/Paddle-Lite/lite/core/optimizer.h:307 RunPasses] == Finished running: variable_place_inference_pass
# [I  8/15 23: 7:24.870 ...island/Paddle-Lite/lite/core/optimizer.h:283 RunPasses] == Running pass: argument_type_display_pass
# [I  8/15 23: 7:24.870 ...island/Paddle-Lite/lite/core/optimizer.h:307 RunPasses] == Finished running: argument_type_display_pass
# [I  8/15 23: 7:24.870 ...island/Paddle-Lite/lite/core/optimizer.h:283 RunPasses] == Running pass: type_precision_cast_pass
# [I  8/15 23: 7:24.871 ...island/Paddle-Lite/lite/core/optimizer.h:307 RunPasses] == Finished running: type_precision_cast_pass
# [I  8/15 23: 7:24.871 ...island/Paddle-Lite/lite/core/optimizer.h:283 RunPasses] == Running pass: variable_place_inference_pass
# [I  8/15 23: 7:24.874 ...island/Paddle-Lite/lite/core/optimizer.h:307 RunPasses] == Finished running: variable_place_inference_pass
# [I  8/15 23: 7:24.874 ...island/Paddle-Lite/lite/core/optimizer.h:283 RunPasses] == Running pass: argument_type_display_pass
# [I  8/15 23: 7:24.874 ...island/Paddle-Lite/lite/core/optimizer.h:307 RunPasses] == Finished running: argument_type_display_pass
# [I  8/15 23: 7:24.874 ...island/Paddle-Lite/lite/core/optimizer.h:283 RunPasses] == Running pass: type_layout_cast_pass
# [I  8/15 23: 7:24.883 ...island/Paddle-Lite/lite/core/optimizer.h:307 RunPasses] == Finished running: type_layout_cast_pass
# [I  8/15 23: 7:24.883 ...island/Paddle-Lite/lite/core/optimizer.h:283 RunPasses] == Running pass: argument_type_display_pass
# [I  8/15 23: 7:24.883 ...island/Paddle-Lite/lite/core/optimizer.h:307 RunPasses] == Finished running: argument_type_display_pass
# [I  8/15 23: 7:24.883 ...island/Paddle-Lite/lite/core/optimizer.h:283 RunPasses] == Running pass: variable_place_inference_pass
# [I  8/15 23: 7:24.886 ...island/Paddle-Lite/lite/core/optimizer.h:307 RunPasses] == Finished running: variable_place_inference_pass
# [I  8/15 23: 7:24.886 ...island/Paddle-Lite/lite/core/optimizer.h:283 RunPasses] == Running pass: argument_type_display_pass
# [I  8/15 23: 7:24.886 ...island/Paddle-Lite/lite/core/optimizer.h:307 RunPasses] == Finished running: argument_type_display_pass
# [I  8/15 23: 7:24.886 ...island/Paddle-Lite/lite/core/optimizer.h:283 RunPasses] == Running pass: runtime_context_assign_pass
# [I  8/15 23: 7:24.886 ...island/Paddle-Lite/lite/core/optimizer.h:307 RunPasses] == Finished running: runtime_context_assign_pass
# [I  8/15 23: 7:24.886 ...island/Paddle-Lite/lite/core/optimizer.h:283 RunPasses] == Running pass: argument_type_display_pass
# [I  8/15 23: 7:24.886 ...island/Paddle-Lite/lite/core/optimizer.h:307 RunPasses] == Finished running: argument_type_display_pass
# [I  8/15 23: 7:24.886 ...island/Paddle-Lite/lite/core/optimizer.h:283 RunPasses] == Running pass: lite_reshape_fuse_pass
# [I  8/15 23: 7:24.886 ...island/Paddle-Lite/lite/core/optimizer.h:307 RunPasses] == Finished running: lite_reshape_fuse_pass
# [I  8/15 23: 7:24.886 ...island/Paddle-Lite/lite/core/optimizer.h:283 RunPasses] == Running pass: memory_optimize_pass
# [I  8/15 23: 7:24.888 ...te/lite/core/mir/memory_optimize_pass.cc:182 CollectLifeCycleByDevice] There are 1 types device var.
# [I  8/15 23: 7:24.888 ...te/lite/core/mir/memory_optimize_pass.cc:231 MakeReusePlan] cluster: batch_norm_13.tmp_2
# [I  8/15 23: 7:24.888 ...te/lite/core/mir/memory_optimize_pass.cc:231 MakeReusePlan] cluster: batch_norm_14.tmp_2
# [I  8/15 23: 7:24.888 ...te/lite/core/mir/memory_optimize_pass.cc:231 MakeReusePlan] cluster: batch_norm_17.tmp_2
# [I  8/15 23: 7:24.888 ...te/lite/core/mir/memory_optimize_pass.cc:231 MakeReusePlan] cluster: conv2d_97.tmp_1
# [I  8/15 23: 7:24.888 ...te/lite/core/mir/memory_optimize_pass.cc:231 MakeReusePlan] cluster: pool2d_1.tmp_0
# [I  8/15 23: 7:24.888 ...te/lite/core/mir/memory_optimize_pass.cc:231 MakeReusePlan] cluster: relu_27.tmp_0
# [I  8/15 23: 7:24.888 ...te/lite/core/mir/memory_optimize_pass.cc:231 MakeReusePlan] cluster: relu_7.tmp_0
# [I  8/15 23: 7:24.888 ...te/lite/core/mir/memory_optimize_pass.cc:231 MakeReusePlan] cluster: shape_0.tmp_0_slice_0
# [I  8/15 23: 7:24.910 ...island/Paddle-Lite/lite/core/optimizer.h:307 RunPasses] == Finished running: memory_optimize_pass
# [I  8/15 23: 7:24.914 ...te/lite/core/mir/generate_program_pass.h:37 GenProgram] insts.size 1
# [I  8/15 23: 7:24.934 ...e-Lite/lite/model_parser/model_parser.cc:481 SaveModelNaive] Save naive buffer model in Deeplab3p_MobileNetv3.nb successfully

# %% [markdown]
# 生成了.nb文件：
#
# <img src = "https://ai-studio-static-online.cdn.bcebos.com/91af3681af3940d692fe5d4e9147f16de4920267a5a64b9f92f2506274d20dca" width = "300" height = "300" />

# %% [markdown]
# ## 9🕳坑先埋在这里
# 部署等一波硬件和finetune

# %% [markdown]
# 请点击[此处](https://ai.baidu.com/docs#/AIStudio_Project_Notebook/a38e5576)查看本环境基本用法.  <br>
# Please click [here ](https://ai.baidu.com/docs#/AIStudio_Project_Notebook/a38e5576) for more detailed instructions.
